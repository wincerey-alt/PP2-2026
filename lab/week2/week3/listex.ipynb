# %% [markdown]
# List 연습 노트 파일입니다.

# %%
temps = [ [1,2], 3, 4, 5] 
values = list(temps)
temps[-1] = 6
temps
values
temps[0][0] = 7
temps
values
# Out:
# [[7, 2], 3, 4, 5]

# %% [markdown]
# 리스트의 합병 연산 (+)
# 리스트의 곱 연산 (*)

# %%
numbers = [10, 20, 30, 40, 50]
print("합=",sum(numbers))  
print("최대값=",max(numbers)) 
print("최소값=",min(numbers))
# Out:
# 합= 150
# 최대값= 50
# 최소값= 10

# %%
fruit1=["사과","바나나"]
fruit2=["복숭아","포도"]
print(fruit1)
# Out:
# ['사과', '바나나']
